# %% [markdown]
# # Forberedelse: Ishuset
#
# Du har fået et fritidsjob i **Ishuset**, en lille iskiosk-kæde i Nordjylland med butikker i Aalborg C, Blokhus, Løkken og Skagen. Chefen har sendt dig et udtræk fra kassesystemet for juni og juli: filen `ishuset.xlsx`.
#
# I dag skal du bare have filen ind i Colab og køre denne notebook. Alt det, vi kan bruge den til, kommer på seminardagen.
#
# **Inden du kører noget:**
#
# 1. Upload `ishuset.xlsx` i filpanelet i venstre side (mappeikonet, derefter upload-knappen). Trinnene står også på portalsiden.
# 2. Vælg derefter **Kørselstid > Kør alle**, eller kør cellerne én ad gangen oppefra.

# %%
# Denne celle tjekker, om filen er uploadet. Du skal ikke forstå koden, bare køre den.
import os

if os.path.exists("ishuset.xlsx"):
    print("Filen er fundet. Kør videre til næste celle.")
else:
    print("Filen mangler: upload ishuset.xlsx i filpanelet til venstre og kør cellen igen.")

# %%
# Denne celle bruger værktøjet pandas. Det lærer du på seminardagen. I dag skal du bare køre den.
import pandas as pd

data = pd.read_excel("ishuset.xlsx")
print(f"Udtrækket indeholder {len(data)} varelinjer.")
data.head()

# %% [markdown]
# Det, du ser ovenfor, er de første 5 varelinjer i udtrækket: hvad der blev solgt, hvor, hvornår, hvor mange og til hvilken stykpris.
#
# På seminardagen arbejder vi med denne fil hele dagen. I dag laver vi kun én lille beregning, som samtidig tjekker, at alt virker på din maskine.

# %%
# numpy er en værktøjskasse til beregninger. Vi henter den ind og giver den det korte navn np.
import numpy as np

# Priserne på Ishusets tre vafler: 1 kugle, 2 kugler, 3 kugler
priser = [38, 50, 62]

print(f"Gennemsnitsprisen for en vaffel er {np.mean(priser)} kr")

# %% [markdown]
# **Din tur.** Ishuset sælger også Softice til 45 kr, Milkshake til 55 kr og Slushice til 35 kr.
#
# I cellen nedenfor: udskift de tre vaffelpriser med de tre priser ovenfor, ret teksten i `print`-linjen, så der står *is uden vaffel* i stedet for *en vaffel*, og kør cellen. Tjek at resultatet giver mening.

# %%
# UDSKIFT de tre priser nedenfor, og ret teksten i print-linjen. Kør derefter cellen.
import numpy as np

priser = [38, 50, 62]

print(f"Gennemsnitsprisen for en vaffel er {np.mean(priser)} kr")

# %% [markdown]
# ## Du er klar til den 15. september
#
# Hvis du er nået hertil, og cellerne er kørt uden fejl, kan du nu:
#
# 1. oprette og køre celler i Colab og hente en notebook som .ipynb-fil
# 2. arbejde med variabler, tal, tekst og lister
# 3. uploade en datafil og køre en notebook, der læser den
# 4. hente en værktøjskasse ind med `import` og bruge den til en beregning
#
# Det er præcis det, seminardagen bygger ovenpå.
#
# **Sidste skridt:** Gå tilbage til portalen og tag selvtjek-quizzen (10 spørgsmål). Den er ikke en prøve, du kan tage den så mange gange, du vil.
#
# Vi ses i Studenterhuset den 15. september kl. 8.30.
